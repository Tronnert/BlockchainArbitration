# %%
import pandas as pd

# %%
df = pd.read_csv("revenue_usd/revenue.csv", sep="\t")
print(df["revenueUSD"])
# Out:
# 0         -0.072472
# 1         -0.002723
# 2        -47.743286
# 3        -15.053711
# 4         -7.827797
#             ...
# 481633   -11.702311
# 481634    -0.041356
# 481635    -0.161449
# 481636    -1.377940
# 481637    -2.315681
# Name: revenueUSD, Length: 481638, dtype: float64

# %%
def func(group):
    old_prices = {}
    base = {"bid": -1, "ask": -1}
    revenue = [0]
    # print(group)
    def sec(singe_dt):
        # print(singe_dt.iloc[0]["bidPrice"])
        singe_dt = singe_dt.sort_values("revenue", ascending=False)
        def thi(now):
            if old_prices.get(now["bidExchange"], base)["bid"] != now["bidPrice"] and \
            old_prices.get(now["askExchange"], base)["ask"] != now["askPrice"]:
                old_prices[now["bidExchange"]] = {"bid": now["bidPrice"], "ask": old_prices.get(now["bidExchange"], base)["ask"]}
                old_prices[now["askExchange"]] = {"bid": old_prices.get(now["askExchange"], base)["ask"], "ask": now["askPrice"]}
                if now["revenueUSD"] > 0:
                    revenue[0] += now["revenueUSD"]
        singe_dt.apply(thi, axis=1)
    group.groupby("dt").apply(sec)
    return revenue[0]

# %%
grb = df.groupby(["base", "quote"], group_keys=True).apply(func)                      
print(grb.sort_values(ascending=False))
# Out:
# base     quote
# ETHF     USDT     21.507657
# MTL      USDT     15.906348
# LUNC     USDT      1.774732
# SUSHI    USDT      0.359120
# SAITAMA  USDT      0.287630
#                     ...
# ETC      USDT      0.000000
# ETH      BTC       0.000000
#          EUR       0.000000
#          USDC      0.000000
# ZRX      USDT      0.000000
# Length: 235, dtype: float64

# %%
print(grb.sum())
# Out:
# 48.07625503006695

# %%
df[df["base"] == "LUNC"].sort_values(by=["revenueUSD"], ascending=False)[["bidPrice", "askPrice", "Qty", "revenue", "revenueUSD", "bidExchange", "askExchange"]].head(20)
# Out:
#         bidPrice  askPrice          Qty   revenue  revenueUSD bidExchange  \
# 325870  0.000138  0.000138  15460903.08  3.950511    3.950577     binance
# 332160  0.000138  0.000138  15460903.08  3.023783    3.023834     binance
# 90056   0.000138  0.000138  15460903.08  3.023783    3.023834     binance
# 90620   0.000138  0.000138  15460903.08  3.023783    3.023834     binance
# 32858   0.000138  0.000138   9523877.10  2.528648    2.528691     binance
# 34082   0.000138  0.000138   9523877.10  2.528648    2.528691     binance
# 278564  0.000138  0.000138   9523877.10  2.528648    2.528691     binance
# 34656   0.000138  0.000138   9523877.10  2.528648    2.528691     binance
# 276664  0.000138  0.000138   9523877.10  2.528648    2.528691     binance
# 35336   0.000138  0.000138   9523877.10  2.528648    2.528691     binance
# 277322  0.000138  0.000138   9523877.10  2.528648    2.528691     binance
# 274362  0.000138  0.000138   9523877.10  2.528648    2.528691     binance
# 277798  0.000138  0.000138   9523877.10  2.528648    2.528691     binance
# 273242  0.000139  0.000138   7405682.91  2.188203    2.188240     binance
# 80020   0.000139  0.000138   7387104.76  2.108916    2.108952     binance
# 324662  0.000139  0.000138   7387104.76  2.108916    2.108952     binance
# 82714   0.000139  0.000138   7387104.76  2.108916    2.108952     binance
# 323918  0.000139  0.000138   7387104.76  2.108916    2.108952     binance
# 82016   0.000139  0.000138   7387104.76  2.108916    2.108952     binance
# 81262   0.000139  0.000138   7387104.76  2.108916    2.108952     binance
#
#        askExchange
# 325870       huobi
# 332160       huobi
# 90056        huobi
# 90620        huobi
# 32858        huobi
# 34082        huobi
# 278564       huobi
# 34656        huobi
# 276664       huobi
# 35336        huobi
# 277322       huobi
# 274362       huobi
# 277798       huobi
# 273242       huobi
# 80020        huobi
# 324662       huobi
# 82714        huobi
# 323918       huobi
# 82016        huobi
# 81262        huobi
