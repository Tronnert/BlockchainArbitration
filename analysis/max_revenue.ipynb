# %%
import pandas as pd

# %%
df = pd.read_csv("revenue/part-00000.csv", sep="\t")
print(df["revenueUSD"])
# Out:
# 0        -1.572117e+00
# 1         2.132445e-08
# 2        -4.733833e+01
# 3        -2.490662e-03
# 4        -7.188427e-02
#               ...
# 837027   -1.923493e+01
# 837028   -7.282506e-01
# 837029   -1.239786e-01
# 837030   -4.871637e+00
# 837031   -2.587640e+00
# Name: revenueUSD, Length: 837032, dtype: float64

# %%
def func(group):
    old_prices = {}
    base = {"bid": -1, "ask": -1}
    revenue = [0]
    # print(group)
    def sec(singe_dt):
        # print(singe_dt.iloc[0]["bidPrice"])
        singe_dt = singe_dt.sort_values("revenue", ascending=False)
        def thi(now):
            if old_prices.get(now["bidExchange"], base)["bid"] != now["bidPrice"] and \
            old_prices.get(now["askExchange"], base)["ask"] != now["askPrice"]:
                old_prices[now["bidExchange"]] = {"bid": now["bidPrice"], "ask": old_prices.get(now["bidExchange"], base)["ask"]}
                old_prices[now["askExchange"]] = {"bid": old_prices.get(now["askExchange"], base)["ask"], "ask": now["askPrice"]}
                if now["revenueUSD"] > 0:
                    revenue[0] += now["revenueUSD"]
        singe_dt.apply(thi, axis=1)
    group.groupby("dt").apply(sec)
    return revenue[0]

# %%
grb = df.groupby(["base", "quote"], group_keys=True).apply(func)                      
print(grb.sort_values(ascending=False))
# Out:
# base      quote
# ETHF      USDT     20.694839
# MANA      USDT      2.304596
# BABYDOGE  USDT      0.500705
# ETHW      USDT      0.126990
# OAS       USDT      0.089808
#                      ...
# EOS       USDT      0.000000
# ETC       BTC       0.000000
#           ETH       0.000000
#           USDT      0.000000
# ZRX       USDT      0.000000
# Length: 256, dtype: float64

# %%
print(grb.sum())
# Out:
# 23.974997665355854

# %%
df[df["base"] == "LUNC"].sort_values(by=["revenueUSD"], ascending=False)[["bidPrice", "askPrice", "Qty", "revenue", "revenueUSD", "bidExchange", "askExchange"]].head(20)
# Out:
#         bidPrice  askPrice         Qty   revenue  revenueUSD bidExchange  \
# 635142  0.000144  0.000144  1216379.32  0.067464    0.067465     binance
# 635800  0.000144  0.000144   892997.05  0.049528    0.049529     binance
# 636588  0.000144  0.000144  1354257.00  0.034524    0.034525     binance
# 219270  0.000144  0.000144   892997.05  0.031686    0.031687     binance
# 634306  0.000144  0.000144   866642.65  0.030751    0.030751     binance
# 224832  0.000144  0.000144  1033504.56  0.026347    0.026347     binance
# 642136  0.000144  0.000144  1033504.56  0.026347    0.026347     binance
# 638230  0.000144  0.000144  1033504.56  0.026347    0.026347     binance
# 639732  0.000144  0.000144  1033504.56  0.026347    0.026347     binance
# 220742  0.000144  0.000144  1033504.56  0.026347    0.026347     binance
# 640494  0.000144  0.000144  1033504.56  0.026347    0.026347     binance
# 643798  0.000144  0.000144  1033504.56  0.026347    0.026347     binance
# 641272  0.000144  0.000144  1033504.56  0.026347    0.026347     binance
# 227066  0.000144  0.000144   323382.27 -0.001448   -0.001448     binance
# 795022  0.000144  0.000144   323382.27 -0.001448   -0.001448     binance
# 646120  0.000144  0.000144   323382.27 -0.001448   -0.001448     binance
# 229506  0.000144  0.000144   323382.27 -0.001448   -0.001448     binance
# 646914  0.000144  0.000144   323382.27 -0.001448   -0.001448     binance
# 231260  0.000144  0.000144   323382.27 -0.001448   -0.001448     binance
# 795740  0.000144  0.000144   323382.27 -0.001448   -0.001448     binance
#
#        askExchange
# 635142      bitget
# 635800      bitget
# 636588      bitget
# 219270      bitget
# 634306      bitget
# 224832      bitget
# 642136      bitget
# 638230      bitget
# 639732      bitget
# 220742      bitget
# 640494      bitget
# 643798      bitget
# 641272      bitget
# 227066      bitget
# 795022      bitget
# 646120      bitget
# 229506      bitget
# 646914      bitget
# 231260      bitget
# 795740      bitget
